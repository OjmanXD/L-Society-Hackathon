# %%
import pickle
import pandas as pd
pkl_filename = "Dataset.pkl"
with open(pkl_filename, 'rb') as file:
    df=pd.read_pickle(file)

# %%
df
# Out:
#     Category Sub_Category_1     Sub_Category_2               Sub_Category_3  \
# 0       O365          email            outlook           connectivity issue
# 1       O365        network  Viatris Utilities                 access issue
# 3       O365    user device        power point                 access issue
# 4       O365    user device    office 365 apps                 access issue
# 5       O365    user device            outlook                 access issue
# ..       ...            ...                ...                          ...
# 653     O365        outlook            mailbox            application issue
# 655     O365        outlook            mailbox            application issue
# 656     O365          teams            add-ins            application issue
# 657     O365          email            mailbox  recieving and sending issue
# 658     O365    user device              files           connectivity issue
#
# ...

# %%
num_classes = len(df['Sub_Category_3'].unique())
num_classes
label_map = {label: i for i, label in enumerate(df['Sub_Category_3'].unique())}
int_labels = [label_map[label] for label in df['Sub_Category_3'].unique()]

# %%
def encodeer_classes(x):
    return(label_map[x])

# %%
df['Sub-Category-3_encoded'] = df['Sub_Category_3'].apply(lambda x: encodeer_classes(x))

import numpy as np
from keras.models import Sequential
from keras.layers import Dense, Dropout,Reshape, LSTM
from keras.utils import to_categorical
from sklearn.model_selection import train_test_split


# Split your data into training and test sets
X_train, X_test, y_train, y_test = train_test_split(df['vector'], df['Sub-Category-3_encoded'], test_size=.25, random_state=104, shuffle=True)
x_train, X_test, Y_train, y_test = train_test_split(df['vector'], df['Sub-Category-3_encoded'], test_size=.7, random_state=104, shuffle=True)

# Convert your vectorized text data into numpy arrays
X_train = np.array(list(X_train))
X_test = np.array(list(X_test))



# Convert your labels to one-hot encoded vectors
y_train = to_categorical(y_train, num_classes)
y_test = to_categorical(y_test, num_classes)


# Define your model architecture
model = Sequential()
model.add(Dense(512, input_dim=1024, activation='relu'))
model.add(Dropout(0.2))
model.add(Reshape((2, 256))) 
model.add(Dropout(0.2))
model.add(LSTM(128))

model.add(Dropout(0.3))
model.add(Dense(num_classes, activation='softmax'))

# Compile your model
from keras.optimizers import SGD
opt = SGD(lr=0.01)

model.compile(loss='categorical_crossentropy', optimizer=opt, metrics=['accuracy'])

# Train your model
model.fit(X_train, y_train, epochs=600, batch_size=20, validation_data=(X_test, y_test))

# Evaluate your model
loss, accuracy = model.evaluate(X_test, y_test)
print("Loss:", loss)
print("Accuracy:", accuracy)
# Out:
# Epoch 1/600
# c:\Users\mkbha\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\optimizers\legacy\gradient_descent.py:114: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)
# 22/22 [==============================] - 2s 23ms/step - loss: 3.3189 - accuracy: 0.1644 - val_loss: 3.0285 - val_accuracy: 0.4303
# Epoch 2/600
# 22/22 [==============================] - 0s 11ms/step - loss: 2.9154 - accuracy: 0.4018 - val_loss: 2.6095 - val_accuracy: 0.4719
# Epoch 3/600
# 22/22 [==============================] - 0s 10ms/step - loss: 2.5740 - accuracy: 0.4315 - val_loss: 2.2815 - val_accuracy: 0.4792
# Epoch 4/600
# 22/22 [==============================] - 0s 8ms/step - loss: 2.3086 - accuracy: 0.4475 - val_loss: 2.0480 - val_accuracy: 0.4866
# Epoch 5/600
# 22/22 [==============================] - 0s 9ms/step - loss: 2.1018 - accuracy: 0.4932 - val_loss: 1.8884 - val_accuracy: 0.5037
# Epoch 6/600
# ...

# %%
model.save('./sub_category_3_model/')
# Out:
# WARNING:absl:Found untraced functions such as lstm_cell_3_layer_call_fn, lstm_cell_3_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: ./sub_category_3_model/assets
# INFO:tensorflow:Assets written to: ./sub_category_3_model/assets

# %%
import pickle
pkl_filename = "sub_category_3_labelmap.pkl"
with open(pkl_filename, 'wb') as file:
    pickle.dump(label_map, file)

# %%
num_classes = len(df['Sub_Category_2'].unique())
num_classes
label_map = {label: i for i, label in enumerate(df['Sub_Category_2'].unique())}
int_labels = [label_map[label] for label in df['Sub_Category_2'].unique()]

# %%
df['Sub-Category-2_encoded'] = df['Sub_Category_2'].apply(lambda x: encodeer_classes(x))

import numpy as np
from keras.models import Sequential
from keras.layers import Dense, Dropout,Reshape, LSTM
from keras.utils import to_categorical
from sklearn.model_selection import train_test_split


# Split your data into training and test sets
X_train, X_test, y_train, y_test = train_test_split(df['vector'], df['Sub-Category-2_encoded'], test_size=.25, random_state=104, shuffle=True)
x_train, X_test, Y_train, y_test = train_test_split(df['vector'], df['Sub-Category-2_encoded'], test_size=.7, random_state=104, shuffle=True)

# Convert your vectorized text data into numpy arrays
X_train = np.array(list(X_train))
X_test = np.array(list(X_test))



# Convert your labels to one-hot encoded vectors
y_train = to_categorical(y_train, num_classes)
y_test = to_categorical(y_test, num_classes)


# Define your model architecture
model = Sequential()
model.add(Dense(512, input_dim=1024, activation='relu'))
model.add(Dropout(0.2))
model.add(Reshape((2, 256))) 
model.add(Dropout(0.2))
model.add(LSTM(128))

model.add(Dropout(0.3))
model.add(Dense(num_classes, activation='softmax'))

# Compile your model
from keras.optimizers import SGD
opt = SGD(lr=0.01)

model.compile(loss='categorical_crossentropy', optimizer=opt, metrics=['accuracy'])

# Train your model
model.fit(X_train, y_train, epochs=600, batch_size=20, validation_data=(X_test, y_test))

# Evaluate your model
loss, accuracy = model.evaluate(X_test, y_test)
print("Loss:", loss)
print("Accuracy:", accuracy)
# Out:
# Epoch 1/600
# c:\Users\mkbha\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\optimizers\legacy\gradient_descent.py:114: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)
# 22/22 [==============================] - 2s 28ms/step - loss: 3.5411 - accuracy: 0.1461 - val_loss: 3.3280 - val_accuracy: 0.2176
# Epoch 2/600
# 22/22 [==============================] - 0s 8ms/step - loss: 3.3028 - accuracy: 0.2123 - val_loss: 3.0846 - val_accuracy: 0.2127
# Epoch 3/600
# 22/22 [==============================] - 0s 7ms/step - loss: 3.1095 - accuracy: 0.2078 - val_loss: 2.8922 - val_accuracy: 0.2127
# Epoch 4/600
# 22/22 [==============================] - 0s 7ms/step - loss: 2.9383 - accuracy: 0.2192 - val_loss: 2.7332 - val_accuracy: 0.2274
# Epoch 5/600
# 22/22 [==============================] - 0s 7ms/step - loss: 2.8083 - accuracy: 0.2420 - val_loss: 2.6033 - val_accuracy: 0.2494
# Epoch 6/600
# ...

# %%
model.save('./sub_category_2_model/')
# Out:
# WARNING:absl:Found untraced functions such as lstm_cell_4_layer_call_fn, lstm_cell_4_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: ./sub_category_2_model/assets
# INFO:tensorflow:Assets written to: ./sub_category_2_model/assets

# %%
import pickle
pkl_filename = "sub_category_2_labelmap.pkl"
with open(pkl_filename, 'wb') as file:
    pickle.dump(label_map, file)

# %%
num_classes = len(df['Sub_Category_1'].unique())
label_map = {label: i for i, label in enumerate(df['Sub_Category_1'].unique())}
int_labels = [label_map[label] for label in df['Sub_Category_1'].unique()]

# %%
df['Sub-Category-1_encoded'] = df['Sub_Category_1'].apply(lambda x: encodeer_classes(x))

import numpy as np
from keras.models import Sequential
from keras.layers import Dense, Dropout,Reshape, LSTM
from keras.utils import to_categorical
from sklearn.model_selection import train_test_split


# Split your data into training and test sets
X_train, X_test, y_train, y_test = train_test_split(df['vector'], df['Sub-Category-1_encoded'], test_size=.25, random_state=104, shuffle=True)
x_train, X_test, Y_train, y_test = train_test_split(df['vector'], df['Sub-Category-1_encoded'], test_size=.7, random_state=104, shuffle=True)


# Convert your vectorized text data into numpy arrays
X_train = np.array(list(X_train))
X_test = np.array(list(X_test))



# Convert your labels to one-hot encoded vectors
y_train = to_categorical(y_train, num_classes)
y_test = to_categorical(y_test, num_classes)


# Define your model architecture
model = Sequential()
model.add(Dense(512, input_dim=1024, activation='relu'))
model.add(Dropout(0.2))
model.add(Reshape((2, 256))) 
model.add(Dropout(0.2))
model.add(LSTM(128))

model.add(Dropout(0.3))
model.add(Dense(num_classes, activation='softmax'))

# Compile your model
from keras.optimizers import SGD
opt = SGD(lr=0.01)

model.compile(loss='categorical_crossentropy', optimizer=opt, metrics=['accuracy'])

# Train your model
model.fit(X_train, y_train, epochs=600, batch_size=20, validation_data=(X_test, y_test))

# Evaluate your model
loss, accuracy = model.evaluate(X_test, y_test)
print("Loss:", loss)
print("Accuracy:", accuracy)
# Out:
# Epoch 1/600
# c:\Users\mkbha\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\optimizers\legacy\gradient_descent.py:114: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)
# 22/22 [==============================] - 3s 40ms/step - loss: 2.7325 - accuracy: 0.3425 - val_loss: 2.2991 - val_accuracy: 0.5232
# Epoch 2/600
# 22/22 [==============================] - 0s 14ms/step - loss: 2.1813 - accuracy: 0.5114 - val_loss: 1.9175 - val_accuracy: 0.5232
# Epoch 3/600
# 22/22 [==============================] - 0s 12ms/step - loss: 1.9269 - accuracy: 0.5114 - val_loss: 1.7818 - val_accuracy: 0.5232
# Epoch 4/600
# 22/22 [==============================] - 0s 16ms/step - loss: 1.8164 - accuracy: 0.5114 - val_loss: 1.7018 - val_accuracy: 0.5232
# Epoch 5/600
# 22/22 [==============================] - 0s 16ms/step - loss: 1.7500 - accuracy: 0.5114 - val_loss: 1.6411 - val_accuracy: 0.5232
# Epoch 6/600
# ...

# %%
model.save('./sub_category_1_model/')
# Out:
# WARNING:absl:Found untraced functions such as lstm_cell_5_layer_call_fn, lstm_cell_5_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: ./sub_category_1_model/assets
# INFO:tensorflow:Assets written to: ./sub_category_1_model/assets

# %%
import pickle
pkl_filename = "sub_category_1_labelmap.pkl"
with open(pkl_filename, 'wb') as file:
    pickle.dump(label_map, file)
