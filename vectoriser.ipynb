# %%
import pandas as pd
df = pd.read_excel("HM_Test set data.xlsx", sheet_name='Email')
# df = pd.read_excel('Data for Category and Subcategory_emal_citrix tower_Manual Categorization.xlsx')

# %%
df
# Out:
#         Category Sub_Category_1     Sub_Category_2      Sub_Category_3  \
# 0           O365          email            outlook  connectivity issue
# 1           O365        network  Viatris Utilities        access issue
# 2            NaN            NaN                NaN                 NaN
# 3           O365    user device        power point        access issue
# 4           O365    user device    office 365 apps        access issue
# ...          ...            ...                ...                 ...
# 1048570      NaN            NaN                NaN                 NaN
# 1048571      NaN            NaN                NaN                 NaN
# 1048572      NaN            NaN                NaN                 NaN
# 1048573      NaN            NaN                NaN                 NaN
# 1048574     O365            NaN                NaN                 NaN
#
#                                          short_description  \
# ...

# %%
df["final disc"]=df["Sub_Category_1"].astype("str")+" "+"|"+" "+df["Sub_Category_2"].astype("str")+" "+"|"+" "+df["Sub_Category_3"].astype("str")+" "+"|"+" "+df["Description"].astype("str")

# %%
# df["final disc"] = df["Description"].astype("str")

# %%
df.dropna(inplace=True)
df
# Out:
#     Category Sub_Category_1     Sub_Category_2               Sub_Category_3  \
# 0       O365          email            outlook           connectivity issue
# 1       O365        network  Viatris Utilities                 access issue
# 3       O365    user device        power point                 access issue
# 4       O365    user device    office 365 apps                 access issue
# 5       O365    user device            outlook                 access issue
# ..       ...            ...                ...                          ...
# 653     O365        outlook            mailbox            application issue
# 655     O365        outlook            mailbox            application issue
# 656     O365          teams            add-ins            application issue
# 657     O365          email            mailbox  recieving and sending issue
# 658     O365    user device              files           connectivity issue
#
# ...

# %%
import spacy_sentence_bert
nlp = spacy_sentence_bert.load_model('en_stsb_roberta_large')

# %%
df['vector'] = df['Description'].apply(lambda x: nlp(x).vector) # type: ignore

# %%
import pickle
pkl_filename = "Dataset.pkl"
with open(pkl_filename, 'wb') as file:
    pickle.dump(df, file)
